# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import pandas as pd

# 1. Nạp dữ liệu Iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# 2. Tách dữ liệu
X = df[iris.feature_names]
Y = df['target']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, train_size=0.7, test_size=0.3)

# 3. Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 4. Huấn luyện mô hình
clf = DecisionTreeClassifier(max_depth=2, random_state=0)
clf.fit(X_train, Y_train)

# 5. Kiểm thử mô hình với 10 dữ liệu đầu tiên
print('Input: \n', X_test[0:9])
print('Predicted Output: ', clf.predict(X_test[0:9]))
print('True Value: ', Y_test.values[0:9])

# 6. Đánh giá mô hình
# 6.1 Ma trận confusion
Y_predict = clf.predict(X_test)
Y_true = Y_test.values
print("\nConfusion Matrix:")
print(confusion_matrix(Y_true, Y_predict))

# 6.2 Accuracy và F1-score
accuracy = accuracy_score(Y_true, Y_predict)
f1 = f1_score(Y_true, Y_predict, average=None)
print("\nAccuracy: ", accuracy)
print("F1-score (per class): ", f1)
# Out:
# Input:
#  [[-0.10694994 -0.55721505  0.70793846  1.51006688]
#  [ 0.1222285  -1.92315077  0.09545238 -0.29318114]
#  [-0.45071761  2.6299683  -1.35224199 -1.32360858]
#  [ 1.6118884  -0.32955909  1.37610509  0.7372463 ]
#  [-1.02366372  0.80872067 -1.29656144 -1.32360858]
#  [ 0.46599617  0.58106472  1.20906343  1.63887031]
#  [-1.02366372  1.03637663 -1.40792255 -1.19480515]
#  [ 0.92435306  0.12575281  0.48521625  0.35083601]
#  [ 1.03894229 -0.55721505  0.5408968   0.22203258]]
# Predicted Output:  [2 1 0 2 0 2 0 1 1]
# True Value:  [2 1 0 2 0 2 0 1 1]
#
# Confusion Matrix:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  3  8]]
#
# Accuracy:  0.9111111111111111
# F1-score (per class):  [1.         0.89473684 0.8       ]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import pandas as pd

# 1. Nạp dữ liệu Iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# 2. Tách dữ liệu
X = df[iris.feature_names]
Y = df['target']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, train_size=0.7, test_size=0.3)

# 3. Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 4. Tạo và huấn luyện mô hình Decision Tree với GridSearchCV
param_grid = {
    'max_depth': [2, 3, 4, 5, 6, 7, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tối ưu
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=0), param_grid, cv=5, scoring='f1_macro')
grid_search.fit(X_train, Y_train)

# In ra các tham số tối ưu
print(f"Best parameters: {grid_search.best_params_}")

# 5. Kiểm tra mô hình với dữ liệu kiểm thử
clf_best = grid_search.best_estimator_
Y_predict = clf_best.predict(X_test)

# 6. Đánh giá mô hình
print("\nConfusion Matrix:")
print(confusion_matrix(Y_test, Y_predict))

accuracy = accuracy_score(Y_test, Y_predict)
f1 = f1_score(Y_test, Y_predict, average='macro')
print("\nAccuracy: ", accuracy)
print("F1-score: ", f1)
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Confusion Matrix:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]
#
# Accuracy:  0.9777777777777777
# F1-score:  0.975983436853002

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine
import pandas as pd

# 1. Nạp dữ liệu Wine
wine = load_wine()
df = pd.DataFrame(wine.data, columns=wine.feature_names)
df['target'] = wine.target

# 2. Tách dữ liệu thành training và test set
X = df[wine.feature_names]
Y = df['target']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, train_size=0.7, test_size=0.3)

# 3. Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 4. Tạo và huấn luyện mô hình Decision Tree với GridSearchCV
param_grid = {
    'max_depth': [2, 3, 4, 5, 6, 7, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Sử dụng GridSearchCV để tìm kiếm các tham số tối ưu
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=0), param_grid, cv=5, scoring='f1_macro')
grid_search.fit(X_train, Y_train)

# In ra các tham số tối ưu
print(f"Best parameters: {grid_search.best_params_}")

# 5. Kiểm tra mô hình với dữ liệu kiểm thử
clf_best = grid_search.best_estimator_
Y_predict = clf_best.predict(X_test)

# 6. Đánh giá mô hình
print("\nConfusion Matrix:")
print(confusion_matrix(Y_test, Y_predict))

accuracy = accuracy_score(Y_test, Y_predict)
f1 = f1_score(Y_test, Y_predict, average='macro')
print("\nAccuracy: ", accuracy)
print("F1-score: ", f1)
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Confusion Matrix:
# [[18  1  0]
#  [ 1 20  1]
#  [ 0  0 13]]
#
# Accuracy:  0.9444444444444444
# F1-score:  0.9468546473850431

# %%
import sklearn
if sklearn.__version__ < '0.20.0':
    raise Exception('Error: required sklearn version >=0.20')

from sklearn import tree
import matplotlib.pyplot as plt

# Visualization with plot_tree
feature_names = iris.feature_names  # List of feature names
class_names = iris.target_names  # List of class labels (species names)

# Plotting the decision tree
plt.figure(figsize=(15,10))
tree.plot_tree(clf,
               feature_names=feature_names,
               class_names=class_names,
               filled=True, 
               rounded=True)  # Removed special_characters=True
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# 1. Nạp dữ liệu Iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Hiển thị số thuộc tính và số objects
print("Số thuộc tính (dimensionality):", df.shape[1] - 1)
print("Số objects (size):", df.shape[0])

# 2. Đặt nhãn và hiển thị số lớp
X = df[iris.feature_names]
Y = df['target']
print("Số lớp (classes):", len(np.unique(Y)))

# 3. Tách dữ liệu thành training data (70%) và test data (30%)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42, train_size=0.7, test_size=0.3)

# 4. Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 5. Tạo và huấn luyện mô hình, điều chỉnh tham số để tìm f-score tốt nhất
best_f1 = 0
best_params = {}

for max_depth in range(1, 6):
    for min_samples_split in range(2, 5):
        clf = DecisionTreeClassifier(max_depth=max_depth, min_samples_split=min_samples_split, random_state=42)
        clf.fit(X_train, Y_train)
        Y_predict = clf.predict(X_test)
        f1 = f1_score(Y_test, Y_predict, average='macro')
        if f1 > best_f1:
            best_f1 = f1
            best_params = {'max_depth': max_depth, 'min_samples_split': min_samples_split}

print("\nBest parameters:", best_params)
print("Best F1-score:", best_f1)

# Huấn luyện mô hình với tham số tốt nhất
clf = DecisionTreeClassifier(**best_params, random_state=42)
clf.fit(X_train, Y_train)

# 6. Test và đánh giá mô hình
Y_predict = clf.predict(X_test)
conf_matrix = confusion_matrix(Y_test, Y_predict)
accuracy = accuracy_score(Y_test, Y_predict)
f1 = f1_score(Y_test, Y_predict, average=None)

print("\nConfusion Matrix:")
print(conf_matrix)
print("\nAccuracy:", accuracy)
print("F1-score (per class):", f1)

# 7. Trực quan hóa cây quyết định
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# Số thuộc tính (dimensionality): 4
# Số objects (size): 150
# Số lớp (classes): 3
#
# Best parameters: {'max_depth': 3, 'min_samples_split': 2}
# Best F1-score: 1.0
#
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Accuracy: 1.0
# F1-score (per class): [1. 1. 1.]

# %%
# Out:
# Input:
#  [[ 0.3100623  -0.50256349  0.484213   -0.05282593]
#  [-0.17225683  1.89603497 -1.26695916 -1.27039917]
#  [ 2.23933883 -0.98228318  1.76840592  1.43531914]
#  [ 0.18948252 -0.26270364  0.36746819  0.35303182]
#  [ 1.15412078 -0.50256349  0.54258541  0.2177459 ]
#  [-0.53399618  0.93659559 -1.38370397 -1.13511325]
#  [-0.29283662 -0.26270364 -0.15788346  0.08245999]
#  [ 1.27470056  0.21701605  0.71770262  1.43531914]
#  [ 0.43064208 -1.94172256  0.36746819  0.35303182]]
# Predicted Output:  [1 0 2 1 1 0 1 2 1]
# True Value:  [1 0 2 1 1 0 1 2 1]
#
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Accuracy:  1.0
# F1-score (per class):  [1. 1. 1.]

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import matplotlib.pyplot as plt
import pandas as pd

# 1. Load breast cancer dataset
cancer = load_breast_cancer()
data = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data['target'] = cancer.target

print("Number of features (dimensionality):", data.shape[1] - 1)
print("Number of objects (size):", data.shape[0])

# 2. Assign labels and display the number of classes
X = data[cancer.feature_names]
Y = data['target']
print("Number of classes:", len(cancer.target_names))
print("Classes:", cancer.target_names)

# 3. Split the data into training (70%) and testing (30%)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7, random_state=42)

# 4. Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 5. Create and train the model
clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train, Y_train)

# 6. Test and evaluate the model
Y_pred = clf.predict(X_test)
conf_matrix = confusion_matrix(Y_test, Y_pred)
accuracy = accuracy_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred, average='weighted')

print("Confusion Matrix:\n", conf_matrix)
print("Accuracy:", accuracy)
print("F1 Score:", f1)

# 7. Visualize the decision tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=cancer.feature_names, class_names=cancer.target_names, filled=True)
plt.title("Decision Tree for Breast Cancer Dataset")
plt.show()

# Display decision tree text representation
print("\nDecision Tree Rules:\n")
print(export_text(clf, feature_names=list(cancer.feature_names)))
# Out:
# Number of features (dimensionality): 30
# Number of objects (size): 569
# Number of classes: 2
# Classes: ['malignant' 'benign']
# Confusion Matrix:
#  [[ 59   4]
#  [  2 106]]
# Accuracy: 0.9649122807017544
# F1 Score: 0.9647902680643604
# Decision Tree Rules:
#
# |--- mean concave points <= 0.08
# |   |--- worst radius <= 0.11
# |   |   |--- area error <= 0.17
# |   |   |   |--- class: 1
# |   |   |--- area error >  0.17
# |   |   |   |--- class: 0
# |   |--- worst radius >  0.11
# |   |   |--- mean texture <= -0.71
# |   |   |   |--- class: 1
# |   |   |--- mean texture >  -0.71
# |   |   |   |--- class: 0
# |--- mean concave points >  0.08
# |   |--- worst texture <= -0.85
# |   |   |--- mean concave points <= 1.13
# |   |   |   |--- class: 1
# |   |   |--- mean concave points >  1.13
# |   |   |   |--- class: 0
# |   |--- worst texture >  -0.85
# |   |   |--- worst area <= -0.29
# |   |   |   |--- class: 1
# |   |   |--- worst area >  -0.29
# |   |   |   |--- class: 0
